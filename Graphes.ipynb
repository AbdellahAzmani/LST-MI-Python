# %% [markdown]
# <center style="font-size:35px;color:red;font-weight:bold"> Initiation à Python</center><br>
# <center style="color:black;font-size:20px"> Complément de cours  </center>
# <center style="color:black;font-size:14px"> Théorie des graphes </center>
# <br>
# <center style="color:black">**Cours du Pr. Abdellah AZMANI**</center>
# <center style="color:black">**Département Génie Informatique**</center>
# <br>
# <center style="color:black">Université Abdelmalek Essaadi</center>
# <center style="color:black">Faculté des Sciences et Techniques</center>
# <center style="color:black">Tanger</center>

# %% [markdown]
# ## Introduction
# Naissance en 1736, communication d’Euler (1707-1783) où il proposait une solution au problème des ponts königsberg
#
# En 1847, Kirchhoff (1824-1887) développait la théorie des arbres pour l’appliquer à l’analyse de circuits électriques.
#
# A partir de 1946, la théorie des graphes a connu un développement intense sous l’impulsion des chercheurs motivés par la résolution des problèmes concrets :
#
#           -  Chemin le plus court / le plus long
#           -  Ordonnancement / planification
#           -  Flot maximum
#           -  Flot de coût minimum
#           -  Affectation
#           -  Voyageur de commerce
#
# ## Graphes non orientés
# ### Définition :
#
# Un graphe G est un couple (V,E) où
#
# V = {v1, v2, ..., vn} est un ensemble fini dont les éléments sont appelés sommets.
# E = {e1, e2, ..., em} est un ensemble fini dont les éléments sont appelés arêtes.
#
# Une arête e de l’ensemble E est définie par une paire non-ordonnée (x,y) de sommets, appelés les extrémités de e
#
# Si l'arête e relie les sommets a et b, on dira que ces sommets sont adjacents , ou encore que l'arête e est incidente avec les sommets a et b.
#
# On appelle ordre d’un graphe le nombre de sommets (n) de ce graphe
#
# ### Exemple :
#
# Ensemble des sommets:
# V = {1, 2, 3, 4, 5}
#
# Ensemble des arêtes:
# E = {(1, 3), (1, 4), (1, 5), (2, 3), (3, 4), (3, 5), (4, 5)}
#
# ![graphe%201.png](attachment:graphe%201.png)
#
# #### Un graphe connexe
# * V = {1, 2, 3, 4}
# * E = {(1,1), (1,3), (1,4), (2,3), (2,3),(3,4)}
# ![1.png](attachment:1.png)
#
# #### Un graphe non connexe
# * V = {1, 2, 3, 4, 5, 6}
# * E = {(1,3), (1,4), (2,3), (3,4),  (5,6)}
# ![2.png](attachment:2.png)
#
# #### Un graphe complet
# * V = {1, 2, 3, 4, 5}
# * E = {(1,2), (1,3), (1,4), (1,5), (2,3), (2,4), (2,5), (3,4),(3,5), (4,5)}
# ![3.png](attachment:3.png)
#
# #### Un graphe biparti
# * V = {1, 2, 3, 4, 5}
# * E = {(1,2), (1,4), (2,3), (2,5), (3,4), (4,5)}
# ![4.png](attachment:4.png)
#
#
# ### Graphe partiel:
#
# Soit G = (V, E) un graphe. Le graphe G' = (V, E') est un graphe partiel de G, si E' est inclus dans E
#
# ### Sous graphe :
#
# Le graphe G’=(A, E(A)) est un sous graphe de G, si A est un sous ensemble de V et E(A) est l'ensemble des arêtes formé de toutes les arêtes de G ayant leurs deux extrémités dans A
#
# * Un graphe partiel d'un sous-graphe est un sous-graphe partiel de G
# * On appelle clique un sous-graphe complet de G
# * On appelle stable un sous-graphe de G sans arêtes
#
# #### Exemples:
# Soit le graphe G = (V, E) où
# * V = { v1, v2, v3, v4, v5 }  et
# * E = { e1 = (v1,v2),  e2 = (v2,v3),  e3 = (v1,v3),  e4 = (v3,v4),  e5 = (v3,v5) }
#
# **Le graphe G**
# ![5.png](attachment:5.png)
#
# **Graphe partiel de G - V'=V et E'={e1, e4, e5}**
# ![6.png](attachment:6.png)
#
# **Sous-graphe de G - V'={v1, v3, v4, v5} et E'={e3, e4, e5}**
# ![7.png](attachment:7.png)
#
# **Une clique de G - V'={v1,v2,v3} et E'={e1, e2, e3}**
# ![8.png](attachment:8.png)
#
# **Un stable de G - V'={v1,v4,v5} et E'={} **
# ![9.png](attachment:9.png)
#
# ### Degré d'un sommet :
#
# Pour un graphe ou un multigraphe, on appelle degré du sommet v, et on note d(v),
# le nombre d‘arêtes incidentes avec ce sommet
#
# ### Degré d'un graphe :
#
# Le degré d'un graphe est le degré maximum de tous ses sommets
#
# Un graphe dont tous les sommets ont le même degré est dit régulier. Si le degré commun est k, alors on dit que le graphe est k-régulier.
#
# * d(v1) = 2
# * d(v2) = 1
# * d(v3) = 3
# * d(v4) = 2
# * d(v5) = 1
# * d(v6) = 1
# * d(G) = 3
# ![10.png](attachment:10.png)
#
# ## Graphes orientés
# ### Définitions :
#
# Un digraphe fini G = (V, E) est défini par l'ensemble fini V = {v1, v2, ..., vn} dont les éléments sont appelés sommets, et par l'ensemble fini E = {e1, e2, ..., em}  dont les éléments sont appelés arcs.
#
# Un arc e de l'ensemble E est défini par une paire ordonnée de sommets
# e = (u, v), on dira que l'arc e va de u à v.
#
# * On note d+(v) le degré extérieur du sommet v
# * On note d-(v) le degré intérieur du sommet v
#
# Le degré d'un sommet orienté est la somme de degré  extérieur et de degré intérieur : d(v) = d+(v) + d-(v )
# ![11.png](attachment:11.png)
#
# ## Chemin et cycle
#
# * Un **chemin** est une liste p=(x1,x2,…., xk) de sommets telle qu'il existe dans le graphe une arête entre chaque paire de sommets successifs.
# * La **longueur** du chemin correspond au nombre d'arêtes parcourues : k-1
# * Un chemin p est **simple** si chaque arête du chemin est visité une seule fois.
# * Un **cycle**  est un chemin simple finissant à son point de départ : x1=xk+1
# * Un chemin p=(x1,x2,...,xk) est **élémentaire** si chacun des sommets du parcours est visité une seule fois
# * Un chemin **élémentaire** est donc un chemin simple et sans cycle
# * Un graphe est **connexe** ssi il existe un chemin entre chaque paire de sommets.
#
# ## Graphes eulériens et hamiltoniens
#
# * Un graphe est **eulérien** s'il est possible de trouver un cycle passant une et une seule fois par toutes les arêtes.
# * Un graphe est **semi-eulérien** s'il est possible de trouver un chemin passant une et une seule fois par toutes les arêtes
# * Un graphe est **hamiltonien** s'il est possible de trouver un cycle passant une et une seule fois par tous les sommets
# * Un graphe est **semi-hamiltonien** s'il est possible de trouver un chemin passant une et une seule fois par tous les sommets.
#
# ### Théorème
# Soit G = (V, E) un graphe simple d'ordre n >= 3. Si pour toute paire {x,y} de sommets non adjacents, on a d(x) + d(y) >= n, alors G est hamiltonien.

# %% [markdown]
# ## Arbres
# ### Définitions :
# * On appelle arbre tout graphe connexe, sans cycles.
# * Un graphe sans cycles et non connexe est appelé une forêt.
# ![12.png](attachment:12.png)
# ![13.png](attachment:13.png)
#
# ### Théorème
# Les affirmations suivantes sont équivalentes pour tout  graphe G = (V, E) ayant n sommets.
# 1. G est un arbe,
# 2. G est sans cycles et connexe,
# 3. G est sans cycles et comporte n-1 arrêtes,
# 4. G est connexe  et comporte n-1 arrêtes,
# 5. Chaque paire {u, v} de  sommets distincts est reliée par un seul chemin simple (et le graphe est sans boucles).
#
# ## Arborescences
# ### Arborescences :
# * On appelle arborescence  un arbre avec un sommet distingué, que l'on appelle la racine.
# * Un rang est la distance du sommet à la racine.
# ![14.png](attachment:14.png)
#
# ### Arborescences ordonnées :
# Une arborescence ordonnée est une arborescence dont les arêtes partant de chaque sommet sont ordonnées.
# ![15.png](attachment:15.png)
#
# ## Matrice et listes d'adjacences
# * Considérons un graphe G = (X,A) comportant n sommets.
#     * La matrice d’adjacence de G est égale à la matrice U = (uij) de dimension n × n
#     * telle que uij = 1 si (i, j)  appartient A (c’est-à-dire (i, j) est une arête) ; 0 sinon
#
# * Si le graphe est non orienté alors il possède une matrice d’adjacence symétrique.
# ![16.png](attachment:16.png)
#
# Un graphe peut être représenté à l’aide d’une table où chaque ligne correspond à un sommet et comporte la liste des successeurs ou des prédécesseurs de ce sommet.
# ![17.png](attachment:17.png)

# %% [markdown]
# ## Plus court chemin
# ### Algorithme de Djikstra:
#
# * Définir S l'ensemble des sommets marqués. M le point de départ et F le point d’arrivé
# * Attribuer au sommet M le couple (0,M)
# * A chaque sommet X prédécesseur de M associer le couple : (dist(X), P(X)), où  dist(X) représente la distance de M à X et P(X) le prédécesseur de X.
# * Attribuer aux autres sommets le couple (∞, ?)
#
# Tant que tous les sommets ne sont pas dans S ,
#
#     ou que le sommet F n’est pas affecté de la plus petite distance :
#         * Choisir parmi les sommets n’appartenant pas à S
#         * Un de ceux dont la distance est minimale. Soit X ce sommet.
#         * Mettre X dans S .
#     Pour chacun des sommets Yi qui lui sont adjacents et qui ne sont pas dans S
#         * Calculer d=distance de X + poids de l’arête [XYi]
#         * Si d est inférieur à la distance provisoire de Yi,
#         * Attribuer à Yi le couple (d, X)
#
#
# #### Exemple (algorithme de Djikstra) :
# Soit le graphe G=(V,E)
# * Déterminer le plus court chemin entre M et F en appliquant l’algorithme de Djikstra
# ![18.png](attachment:18.png)
#
# * Initiation :  S = {} ;
# ![19.png](attachment:19.png)
# **Le plus court chemin est : M->L->P->E-F**
#
#
#
# ### Algorithme Ford-Bellman :
#
# Permet la recherche des plus courts chemins reliant un sommet S1 à tous les sommets du graphe
#
# **Algoritme :**
# booléen Bellman_Ford( G, s)
#     initialisation ( G, s)  // les poids de tous les sommets sont mis à +infini
#                             // le poids du sommet initial à 0 ;
#             * pour i=1 jusquà Nombre de sommets -1 faire
#                 * pour chaque arc (u, v) du graphe faire
#                     * d := poids(u) + poids(arc(u, v));
#                     * si d <poids(v) alors
#                         * pred(v) := u ;
#                         * poids(v) := d;
#                 * pour chaque arc (u, v) du graphe faire
#                     * si poids(u) + poids(arc(u, v)) <poids(v) alors
#                         * retourner faux
#             * retourner vrai
#
# ##  Réseaux de Transport et flots
# ### Réseau de transport :
# Un réseau de transport est un graphe orienté, connexe, sans boucle et valué, où chaque arc est associé à un nombre c(u) , appelé "capacité" de l'arc u.
# * Il existe un seul noeud s arbitraire appelé l'entrée du réseau, ou la source.
# * Il existe également un seul noeud t arbitraire appelé la sortie du réseau.
# * Entre les noeuds s et t, il peut exister des noeuds intermédiaires.
# ![20.png](attachment:20.png)
#
# ### Définition :
# Un flot f dans un réseau de transport est une fonction qui associe à chaque arc u une quantité f(u) qui représente la quantité de flot qui passe par cet arc, en provenance de la source et en destination du puits.
# ![21.png](attachment:21.png)
#
# ### Loi de Kirchhoff :
# La somme des intensités qui arrivent au noeud est égale à la somme des intensités qui en repartent.
# ![22.png](attachment:22.png)
# ![23.png](attachment:23.png)
#
# ### ALGORITHME DE FORD-FULKERSON :
#
# * pour tout arc u, f(u) = 0.
# * chercher une chaîne reliant la source au puits, telle que son flot peut être augmenté
# * Si on n'en trouve pas, le problème est résolu ,
# * Sinon, on augmente le flot sur cette chaîne, recommence à chercher une chaîne augmentante et ainsi de suite
#
# * L'augmentation de flot maximum pour une chaîne est le minimum des écarts entre le flot courant et le flot maximal pour les arcs directs ou le flot courant pour les arcs indirects.
#     - pour tout arc u direct, f(u) < c(u),
#     - pour tout arc u indirect, f(u) > 0.
#
# * Le flot f sur cette chaîne C peut être augmenté de:
# ![24.png](attachment:24.png)
#
# #### Exemple :
# Voici une chaîne augmentante de A à E faisant partie d'un réseau de transport.
# ![25.png](attachment:25.png)
# Dans cette chaîne, on peut augmenter le flot de:
# * 3 entre A et B,
# * 2 entre B et C,
# * 1 entre C et D,
# * 5 entre D et E.
#
# On augmentera donc de 1 le flot dans cette chaîne.
#
# Ce qui signifie:
# * Augmenter de 1 le flot entre A et B,
# * Augmenter de 1 le flot entre B et C,
# * Diminuer de 1 le flot entre D et C,
# * Augmenter de 1 le flot entre D et E.
# ![26.png](attachment:26.png)
